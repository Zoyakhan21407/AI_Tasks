# %%
Roll No: 21407,21413
Subject:- Artificial Intelligence
Semester:- 6th

# %% [markdown]
# # Imports Libaray

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# # Load the Dataset

# %% [markdown]
# ### read_csv() assumes data has a header

# %%
path = "diabetes .csv"
df = pd.read_csv(path)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148           72.0             35      0.0  33.6
# 1       85           66.0             29      0.0  26.6
# 2      183           64.0              0      0.0  23.3
# 3       89           66.0             23     94.0  28.1
# 4      137           40.0             35    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351  31.0        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
df.tail()
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763      101           76.0             48    180.0  32.9
# 764      122           70.0             27      0.0  36.8
# 765      121           72.0             23    112.0  26.2
# 766      126           60.0              0      0.0  30.1
# 767       93           70.0             31      0.0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0

# %%
df.sample(10)
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 369      133          102.0             28    140.0  32.8
# 175      179           72.0             42    130.0  32.7
# 533       91            0.0              0      0.0  29.8
# 757      123           72.0              0      0.0  36.3
# 559       85           74.0              0      0.0  30.1
# 284      108           80.0              0      0.0  27.0
# 612      168           88.0             42    321.0  38.2
# 616      117           96.0              0      0.0  28.7
# 110      171           72.0             33    135.0  33.3
# 295      151           62.0             31    120.0  35.5
#
#      DiabetesPedigreeFunction   Age  Outcome
# 369                     0.234  45.0        1
# 175                     0.719  36.0        1
# 533                     0.501  31.0        0
# 757                     0.258  52.0        1
# 559                     0.300  35.0        0
# 284                     0.259  52.0        1
# ...

# %%
df.shape
# Out:
# (768, 8)

# %%
df.dtypes
# Out:
# Glucose                       int64
# BloodPressure               float64
# SkinThickness                 int64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                       int64
# dtype: object

# %%
df["Age"].isnull().sum()
# Out:
# 4

# %%
df["BloodPressure"].isnull().sum()
# Out:
# 4

# %%
Bmean=df["BloodPressure"].mean()

# %%
Bmean
# Out:
# 69.07853403141361

# %%
df["BloodPressure"].replace("?", np.nan, inplace = True)

# %%
df["BloodPressure"]= pd.to_numeric(df["BloodPressure"])

# %%
df["BloodPressure"].replace(np.nan, Bmean, inplace = True)

# %%
df["BloodPressure"].isnull().sum()
# Out:
# 0

# %%
df["Insulin"].isnull().sum()
# Out:
# 1

# %%
df["Insulin"].replace("?", np.nan, inplace = True)

# %%
Imean=df["Insulin"].mean()

# %%
df["Insulin"].replace(np.nan, Imean, inplace = True)

# %%
df["Insulin"].isnull().sum()
# Out:
# 0

# %%
df["BMI"].isnull().sum()
# Out:
# 1

# %%
BMmean= df["BMI"].mean()

# %%
BMmean
# Out:
# 32.000651890482374

# %%
df["BMI"].replace("?", np.nan, inplace = True)

# %%
df["BMI"]= pd.to_numeric(df["BMI"])

# %%
df["BMI"].replace(np.nan, BMmean, inplace = True)

# %%
df["BMI"].isnull().sum()
# Out:
# 0

# %%
df["Age"].isnull().sum()
# Out:
# 4

# %%
Agmean= df["Age"].mean()

# %%
Agmean
# Out:
# 33.238219895287955

# %%
df["Age"].replace("?", np.nan, inplace = True)

# %%
df["Age"]= pd.to_numeric(df["Age"])

# %%
df["Age"].replace(np.nan, Agmean, inplace = True)

# %%
df["Age"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean   120.894531      69.078534      20.536458   79.788787   32.000652
# std     31.972618      19.327119      15.952218  115.243621    7.880985
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%     99.000000      63.500000       0.000000    0.000000   27.300000
# 50%    117.000000      72.000000      23.000000   30.500000   32.000000
# 75%    140.250000      80.000000      32.000000  127.250000   36.600000
# max    199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.238220    0.348958
# std                    0.331329   11.718039    0.476951
# min                    0.078000   21.000000    0.000000
# ...

# %% [markdown]
# # Data cleaning

# %%
df.shape
# Out:
# (768, 8)

# %%
df=df.drop_duplicates()#remove duplictes

# %%
df.shape
# Out:
# (768, 8)

# %% [markdown]
# # check no 0f zero values in dataset

# %%
print("No of zero values in Glucose:",df[df["Glucose"]==0].shape[0])
# Out:
# No of zero values in Glucose: 5

# %%
print("No of zero values in BloodPlessure:",df[df["BloodPressure"]==0].shape[0])
# Out:
# No of zero values in BloodPlessure: 35

# %%
print("No of zero values in SkinThickness:",df[df["SkinThickness"]==0].shape[0])
# Out:
# No of zero values in SkinThickness: 227

# %%
print("No of zero values in Insulin:",df[df["Insulin"]==0].shape[0])
# Out:
# No of zero values in Insulin: 374

# %%
print("No of zero values in BMI:",df[df["BMI"]==0].shape[0])
# Out:
# No of zero values in BMI: 11

# %%
print("No of zero values in Age:",df[df["Age"]==0].shape[0])
# Out:
# No of zero values in Age: 0

# %% [markdown]
# # Replace no. of zero values with mean  of that column

# %%
df["Glucose"]=df["Glucose"].replace(0,df["Glucose"].mean())

# %%
df["BloodPressure"]=df["BloodPressure"].replace(0,df["BloodPressure"].mean())

# %%
df["SkinThickness"]=df["SkinThickness"].replace(0,df["SkinThickness"].mean())

# %%
df["Insulin"]=df["Insulin"].replace(0,df["Insulin"].mean())

# %%
df["BMI"]=df["BMI"].replace(0,df["BMI"].mean())

# %%
print("No of zero values in BloodPlessure:",df[df["BloodPressure"]==0].shape[0])
# Out:
# No of zero values in BloodPlessure: 0

# %%
df.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean   121.681605      72.226644      26.606479  118.644265   32.458995
# std     30.436016      12.077402       9.631241   93.086532    6.871185
# min     44.000000      24.000000       7.000000   14.000000   18.200000
# 25%     99.750000      64.000000      20.536458   79.788787   27.575000
# 50%    117.000000      72.000000      23.000000   79.788787   32.000652
# 75%    140.250000      80.000000      32.000000  127.250000   36.600000
# max    199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age     Outcome
# count                768.000000  768.000000  768.000000
# mean                   0.471876   33.238220    0.348958
# std                    0.331329   11.718039    0.476951
# min                    0.078000   21.000000    0.000000
# ...

# %% [markdown]
# # Data visulization

# %% [markdown]
# # Histrograms

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# # Scatterplot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize = (20, 20));

# %% [markdown]
# # pairplot

# %%
sns.pairplot(data = df, hue = "Outcome")
plt.show()

# %% [markdown]
# # Analyzing relaionships between variables

# %% [markdown]
# ### Coorelation Analysis

# %%
import seaborn as sns

# %% [markdown]
# #### get coorelation of each features dataset

# %%
cormat = df.corr()
top_corr_features = cormat.index
plt.figure(figsize = (10,10))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# # Split the data item into X and Y

# %%
target_name = 'Outcome'
y = df[target_name]
x = df.drop(target_name, axis=1)

x.head()
# Out:
#    Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0    148.0           72.0      35.000000   79.788787  33.6
# 1     85.0           66.0      29.000000   79.788787  26.6
# 2    183.0           64.0      20.536458   79.788787  23.3
# 3     89.0           66.0      23.000000   94.000000  28.1
# 4    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627  50.0
# 1                     0.351  31.0
# 2                     0.672  32.0
# 3                     0.167  21.0
# 4                     2.288  33.0

# %% [markdown]
# # Apply feature scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
SSX = scaler.transform(x)

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
X_train, x_test, Y_train, y_test = train_test_split(SSX, y, test_size=0.2, random_state=7)

# %%
X_train.shape,y_test.shape
# Out:
# ((614, 7), (154,))

# %% [markdown]
# # Build the CLASSIFICATION Algorithms

# %% [markdown]
# ## 1: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='liblinear', multi_class='ovr')
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %% [markdown]
# ## 2: KNeighborsClassifier(KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## 3: Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Making Prediction

# %% [markdown]
# ### making prediction on test by using logistic Regression

# %%
x_test.shape
# Out:
# (154, 7)

# %%
lr_pred=lr.predict(x_test)

# %%
lr_pred.shape
# Out:
# (154,)

# %% [markdown]
# ### making prediction on test by using KNN

# %%
knn_pred=knn.predict(x_test)

# %%
knn_pred.shape
# Out:
# (154,)

# %% [markdown]
# ### making prediction on test by using Decision tree

# %%
dt_pred=dt.predict(x_test)

# %% [markdown]
# # Model Evalution

# %% [markdown]
# ## Tain score and Test score of Logistic Regression

# %%
from sklearn.metrics import accuracy_score
print("Train accuracy of Logistic Regression: ",lr.score(X_train,Y_train)*100)
print("Acuracy (Test) score of Logistic Regression: ",lr.score(X_train,Y_train)*100)
print("Acuracy (Test) score of Logistic Regression: ",accuracy_score(y_test,lr_pred)*100)
# Out:
# Train accuracy of Logistic Regression:  77.68729641693811
# Acuracy (Test) score of Logistic Regression:  77.68729641693811
# Acuracy (Test) score of Logistic Regression:  78.57142857142857

# %% [markdown]
# # Tain score and Test score of KNN

# %%
from sklearn.metrics import accuracy_score
print("Train accuracy of KNN: ",knn.score(X_train,Y_train)*100)
print("Acuracy (Test) score of KNN: ",knn.score(X_train,Y_train)*100)
print("Acuracy (Test) score of KNN: ",accuracy_score(y_test,knn_pred)*100)
# Out:
# Train accuracy of KNN:  79.96742671009773
# Acuracy (Test) score of KNN:  79.96742671009773
# Acuracy (Test) score of KNN:  78.57142857142857

# %% [markdown]
# # Tain score and Test score of Decision Tree

# %%
from sklearn.metrics import accuracy_score
print("Train accuracy of Decision Tree: ",lr.score(X_train,Y_train)*100)
print("Acuracy (Test) score of Decision Tree: ",lr.score(X_train,Y_train)*100)
print("Acuracy (Test) score of Decision Tree: ",accuracy_score(y_test,dt_pred)*100)
# Out:
# Train accuracy of Decision Tree:  77.68729641693811
# Acuracy (Test) score of Decision Tree:  77.68729641693811
# Acuracy (Test) score of Decision Tree:  73.37662337662337

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
df.head()
# Out:
#    Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0    148.0           72.0      35.000000   79.788787  33.6
# 1     85.0           66.0      29.000000   79.788787  26.6
# 2    183.0           64.0      20.536458   79.788787  23.3
# 3     89.0           66.0      23.000000   94.000000  28.1
# 4    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351  31.0        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
X = df[ ["Glucose","BloodPressure","SkinThickness","Insulin","BMI","Age"] ]
Y = df["Outcome"]

# %%
linear_model.fit(X,Y)
# Out:
# LinearRegression()

# %%
print("c_0 = ", linear_model.intercept_)
print("c_1 = ", linear_model.coef_)
# Out:
# c_0 =  -1.0293418711593108
# c_1 =  [ 0.00670592 -0.00154601 -0.00036406 -0.00019474  0.01613486  0.00550709]

# %%
linear_model.predict(np.array([[155,73,33,120,40.1,53]]))
# Out:
# array([0.80071804])
